# %% [markdown]
# # 테스트다

# %%
pip install pandas openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.9 MB 10.6 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 13.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 9.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.4 MB 4.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.4 MB 4.3 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.4 MB 4.5 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.4 MB 4.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.4 MB 4.8 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('score.xlsx', index_col='지원번호')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df = pd.read_excel('score.xlsx', index_col='지원번호')
#       2 print(df.head())
#
# File c:\Users\bt10471\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
df.loc['1번', '국어'] = 95
df.to_excel('score_modified.xlsx')

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   95   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
